# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
days = ['Day 1', 'Day 2', 'Day 3', 'Day 4', 'Day 5']
visitors = np.random.randint(50000, 200000, size=5)
cities = ['Prayagraj', 'Varanasi', 'Lucknow', 'Kanpur', 'Agra']
participants = np.random.randint(3000, 15000, size=5)
visitors
#array([122038, 132960,  78229, 108392, 143408], dtype=int32)
# Out:
# array([188580, 147139, 199381,  83162, 120311])

# %%
df_visitors = pd.DataFrame({'Day': days, 'Visitors': visitors})
df_participants = pd.DataFrame({'City': cities, 'Participants': participants})
df_visitors
df_participants
# Out:
#         City  Participants
# 0  Prayagraj         12266
# 1   Varanasi          4786
# 2    Lucknow          4281
# 3     Kanpur         10031
# 4       Agra          6299

# %%
plt.figure(figsize=(8, 5))
plt.plot(df_visitors['Day'], df_visitors['Visitors'], marker='.', color='red')
plt.xlabel('Days')
plt.ylabel('Number of Visitors')
plt.title('Visitors over different days')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.bar(df_participants['City'], df_participants['Participants'], color='orange')
plt.xlabel('Cities')
plt.ylabel('Number of Participants')
plt.title('Participants by city')
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(8, 5))
x = np.arange(1, 6)
plt.plot(x, visitors, label='Visitors Trend', linestyle=':', marker='o')
plt.plot(x, participants, label='Participants Trend', linestyle='-.', marker='x')
plt.xlabel('Days/Cities Index')
plt.ylabel('Count')
plt.title('Visitors & Participants Trend')
plt.legend()
plt.grid(True)
plt.show()
